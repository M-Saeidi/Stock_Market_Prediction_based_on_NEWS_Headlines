# %%
import requests
import json
import pandas

# %%
My_NEWSAPI = 'c7522f7e282e48dbb79f7924e451ccc6'
headers = {'Authorization': My_NEWSAPI}
top_headlines_url = 'https://newsapi.org/v2/top-headlines'
everything_news_url = 'https://newsapi.org/v2/everything'
sources_url = 'https://newsapi.org/v2/sources'

# %%
# Top headlines: Check NEWSAPI.org for more info
headlines_payload = {'category': 'business', 'country': 'us'}
response = requests.get(url=top_headlines_url, headers=headers, params=headlines_payload)

# %%
# Everythings: Check NEWSAPI.org for more info
everything_payload = {'qInTitle': 'google', 'language': 'en', 'from': '2020-07-02', 'to': '2020-08-01', 'sortBy': 'publishedAt'}
response = requests.get(url=everything_news_url, headers=headers, params=everything_payload)

# %%
# Sources: Check NEWSAPI.org for more info
sources_payload = {'category': 'general', 'language': 'en', 'country': 'us'}
response = requests.get(url=sources_url, headers=headers, params=sources_payload)

# %%
# Printing response
pretty_json_output = json.dumps(response.json(), indent=4)
print(pretty_json_output)
# Out:
# {
#     "status": "ok",
#     "totalResults": 7025,
#     "articles": [
#         {
#             "source": {
#                 "id": null,
#                 "name": "Hotukdeals.com"
#             },
#             "author": "Brutes",
#             "title": "108\u00b0 - 2 X TP-Link Tapo Smart Plug Wi-Fi Outlet, Works with Amazon Alexa (Echo and Echo Dot), Google Home - \u00a316.99 Prime/+\u00a34.49 NP @ Amazon UK",
#             "description": "Decent price for 2 pack.  :) <br /><br />You can get \u00a31 reward if you choose to do \"<strong>No-Rush Delivery\" </strong>at checkout.<br /><img src=\"https://images.hotukdeals.com/threads/content/pa5xz/3517272.jpg\" data-image=\"3517272-pa5xz\" data-height=\"239\" da\u2026",
#             "url": "https://www.hotukdeals.com/deals/2-x-tp-link-tapo-smart-plug-wi-fi-outlet-works-with-amazon-alexa-echo-and-echo-dot-google-home-ps1699-primeps449-np-at-amazon-uk-3517272",
#             "urlToImage": "https://images.hotukdeals.com/threads/thread_full_screen/default/3517272_1.jpg",
#             "publishedAt": "2020-08-01T23:56:08Z",
#             "content": null
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Slashdot.org"
#             },
#             "author": "feedfeeder",
#             "title": "Google starts testing its replacement for third-party cookies",
#             "description": "Google has taken one step closer to banishing third-party cookies from Chrome. The internet giant has started testing its trust tokens with developers, with promises that more would move to live tests &ldquo;soon.&rdquo; As before, the company hoped to phase \u2026",
#             "url": "https://slashdot.org/firehose.pl?op=view&amp;id=134176699",
#             "urlToImage": null,
#             "publishedAt": "2020-08-01T23:12:08Z",
#             "content": "If builders built buildings the way programmers wrote programs,\r\nthen the first woodpecker to come along would destroy civilization."
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Forbes"
#             },
#             "author": "Ewan Spence, Senior Contributor, Ewan Spence, Senior Contributorhttps://www.forbes.com/sites/ewanspence/",
#             "title": "Apple\u2019s Radical Macbook Pro Is A Danger To Google",
#             "description": "Not only is Apple disrupting the MacBook and Mac market with its move to ARM-based processors, it\u2019s also going to have an impact on the wider market. Google will have to consider the danger to its Chromebook project .",
#             "url": "https://www.forbes.com/sites/ewanspence/2020/08/01/apple-macbook-pro-arm-intel-google-chromeos-chromebook-comparison/",
#             "urlToImage": "https://thumbor.forbes.com/thumbor/fit-in/1200x0/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F5f25ee208c5b1253b94af113%2F0x0.jpg",
#             "publishedAt": "2020-08-01T22:43:04Z",
#             "content": "Not only is Apple disrupting the MacBook and Mac market with its move to ARM-based processors, its also going to have an impact on the wider marketplace. Microsoft will be forced to accelerate its Wi\u2026 [+3633 chars]"
#         },
#         {
#             "source": {
#                 "id": "engadget",
#                 "name": "Engadget"
#             },
#             "author": "Jon Fingas",
#             "title": "Google starts testing its replacement for third-party cookies",
#             "description": "Google has taken one step closer to banishing third-party cookies from Chrome. The internet giant has started testing its trust tokens with developers, with promises that more would move to live tests \u201csoon.\u201d As before, the company hoped to phase out...",
#             "url": "https://www.engadget.com/google-tests-ad-trust-tokens-223104543.html",
#             "urlToImage": "https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-uploaded-images%2F2020-08%2F9f60d2f0-d426-11ea-bfbe-cc2711f8dc6e&client=amp-blogside-v2&signature=c2edaae167631aaeed41021806364ce77f74bc46",
#             "publishedAt": "2020-08-01T22:31:04Z",
#             "content": "Google has taken one step closer to banishing third-party cookies from Chrome. The internet giant has started testing its trust tokens with developers, with promises that more would move to live test\u2026 [+451 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Seeking Alpha"
#             },
#             "author": "David Jackson",
#             "title": "Apple, Amazon, Microsoft, Google, and Facebook confound index skeptics, as their earnings beats drive the S&P 500 to even greater concentration",
#             "description": "Five stocks -- Microsoft, Apple, Amazon, Facebook and Google -- now account for 21.65% of the S&P 500, traded through the popular S&P 500 ETFs, from StateStreet (NYSEARCA:SPY), iShares (NYSEARCA:IVV), and Vanguard (NYSEARCA:VOO).Over the last month, their sha\u2026",
#             "url": "https://seekingalpha.com/news/3598681-apple-amazon-microsoft-google-and-facebook-confound-index-skeptics-earnings-beats-drive-s-and",
#             "urlToImage": "https://static3.seekingalpha.com/assets/og_image_192-59bfd51c9fe6af025b2f9f96c807e46f8e2f06c5ae787b15bf1423e6c676d4db.png",
#             "publishedAt": "2020-08-01T22:21:29Z",
#             "content": "Five stocks -- Microsoft, Apple, Amazon, Facebook and Google -- now account for 21.65% of the S&amp;P 500, traded through the popular S&amp;P 500 ETFs, from StateStreet (NYSEARCA:SPY), iShares (NYSEA\u2026 [+1200 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "X-ing.space"
#             },
#             "author": "xingyzt",
#             "title": "Show HN: Google Meet Studio Mini \u2013 Change your appearance with a browser script",
#             "description": "Article URL: https://x-ing.space/mercator\nComments URL: https://news.ycombinator.com/item?id=24024131\nPoints: 2\n# Comments: 0",
#             "url": "https://x-ing.space/mercator/",
#             "urlToImage": "https://x-ing.space/mercator/icon.png",
#             "publishedAt": "2020-08-01T21:42:09Z",
#             "content": "Logo of Google Meet Filters &amp; Transforms\r\nDo stuff.\r\n(C) Xing 2020.\r\nChrome Web Store\r\nFirefox Addons\r\nGreasyfork Scripts\r\nTest it out! \r\nGoogle Meet Studio Mini gives you fine control over your \u2026 [+1393 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Freerepublic.com"
#             },
#             "author": "Breitbart",
#             "title": "Rep. Greg Steube Grills Google CEO Sundar Pichai over Deletion of America\u0092s Frontline Doctors Video",
#             "description": "Rep. Greg Steube (R-FL) grilled Google CEO Sundar Pichai today over the removal of footage from a recent press conference held by the organization America\u0092s Frontline Doctors. Steube argued, the videos are \u0093free expression of speech and you have these doctors\u2026",
#             "url": "https://www.freerepublic.com/focus/f-news/3870634/posts",
#             "urlToImage": null,
#             "publishedAt": "2020-08-01T21:38:02Z",
#             "content": "Skip to comments.\r\nRep. Greg Steube Grills Google CEO Sundar Pichai over Deletion of Americas Frontline Doctors VideoBreitbart ^\r\n | july 30 2020\r\n | Lucas Nolan\r\nPosted on 08/01/2020 2:38:02 PM PDT \u2026 [+3534 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Pypi.org"
#             },
#             "author": "idaniel.liu@gmail.com",
#             "title": "google-play-store added to PyPI",
#             "description": "Google Play Store application scraper",
#             "url": "https://pypi.org/project/google-play-store/",
#             "urlToImage": "https://pypi.org/static/images/twitter.90915068.jpg",
#             "publishedAt": "2020-08-01T21:21:58Z",
#             "content": null
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Stackoverflow.com"
#             },
#             "author": "Stack Overflow",
#             "title": "Problem with Samesite in Google Login Popup",
#             "description": "In my project I use Google Login. This functionality stopped working few weeks ago. I run login with Google in iframe. It just closes the window and nothing happens. Inside dev tools there is the following warnings\n\nA cookie associated with a cross-site resou\u2026",
#             "url": "https://stackoverflow.com/questions/63209980/problem-with-samesite-in-google-login-popup",
#             "urlToImage": "https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon@2.png?v=73d79a89bded",
#             "publishedAt": "2020-08-01T21:08:17Z",
#             "content": "In my project I use Google Login. This functionality stopped working few weeks ago. I run login with Google in iframe. It just closes the window and nothing happens. Inside dev tools there is the fol\u2026 [+14 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Mobileread.com"
#             },
#             "author": "droopy",
#             "title": "Best/recommended way to export selected contacts from Google Contacts to Kobo Forma",
#             "description": "I'd like to save some contact information from selected contacts in my Google Contacts to my Kobo Forma. \nIt looks like Google Contacts can export as:\n1. Google CSV\n2. Outlook CSV\n3. vCard (for iOS contacts)\n\n1. Which should I choose?\n2. After I choose one of\u2026",
#             "url": "https://www.mobileread.com/forums/showthread.php?s=8826731545d227a1de0c41b8edc74dcd&p=4018536#post4018536",
#             "urlToImage": null,
#             "publishedAt": "2020-08-01T20:58:35Z",
#             "content": "Moderator NoticeI can't fathom how this is relevant to the calibre application \r\nIf someone wants to tell me where they think it should be, I'll move it.\r\nBR"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Bitsandpieces.us"
#             },
#             "author": "Jonco",
#             "title": "I don\u2019t need Google\u2026",
#             "description": "Thanks, s&f",
#             "url": "https://www.bitsandpieces.us/2020/08/01/i-dont-need-google/",
#             "urlToImage": "https://www.bitsandpieces.us/wp-content/uploads/2020/07/I-dont-need-Google....jpg",
#             "publishedAt": "2020-08-01T20:00:13Z",
#             "content": null
#         },
#         {
#             "source": {
#                 "id": "google-news",
#                 "name": "Google News"
#             },
#             "author": "Richard Gao",
#             "title": "20 US states are working on contact tracing apps using Google and Apple tracking tech",
#             "description": "These states cover roughly 45% of the US population\n\nApple and Google don't often collaborate, but they came together to create an API for a Bluetooth-based coronavirus exposure notification system called the Exposure Notifications System (ENS). Back when thi\u2026",
#             "url": "http://feedproxy.google.com/~r/AndroidPolice/~3/yLo_9q9XP_8/",
#             "urlToImage": null,
#             "publishedAt": "2020-08-01T19:58:51Z",
#             "content": null
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "PocketNow"
#             },
#             "author": "Samuel Martinez",
#             "title": "New Google Pixel 4a leaks include specs and price leaked",
#             "description": "We could have a full list of specs, new leaked images and even the price of the upcoming Google Pixel 4a\nThe post New Google Pixel 4a leaks include specs and price leaked appeared first on Pocketnow.",
#             "url": "https://pocketnow.com/new-google-pixel-4a-leaks-include-specs-and-price-leaked",
#             "urlToImage": "https://pocketnow.com/wp/../files/2020/08/1-Google-Pixel-4a-scaled.jpg",
#             "publishedAt": "2020-08-01T18:41:56Z",
#             "content": "We don\u2019t know everything behind the delay of the Google Pixel 4a, but we may finally see it launched on Monday. Now, we have received tons of rumors, leaks, videos, and more concerning the Pixel 3a s\u2026 [+2398 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Hotukdeals.com"
#             },
#             "author": "PaulHM",
#             "title": "127\u00b0 - Unlocked Google Pixel 3a down to \u00a3289 at Carphone Warehouse",
#             "description": "The Google Pixel 3a was announced just over a Year ago. It is now down to its lowest ever price with Carphone Warehouse. It has all the quality of a Google Android phone and one of the best cameras available on any phone for taking photos at night.",
#             "url": "https://www.hotukdeals.com/deals/unlocked-google-pixel-3a-down-to-ps289-at-carphone-warehouse-3517161",
#             "urlToImage": "https://images.hotukdeals.com/threads/thread_full_screen/default/3517161_1.jpg",
#             "publishedAt": "2020-08-01T18:39:49Z",
#             "content": null
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Slashdot.org"
#             },
#             "author": "EditorDavid",
#             "title": "Google Threatens to Remove All Danish Music From YouTube",
#             "description": "YouTube is \"embroiled in a very public spat with songwriters and music publishers in Denmark,\" according to one music-industry news site. They cite Koda, the group that collects royalties and licensing fees for musicians, as saying that YouTube is now threate\u2026",
#             "url": "https://tech.slashdot.org/story/20/07/31/2350241/google-threatens-to-remove-all-danish-music-from-youtube",
#             "urlToImage": "https://a.fsdn.com/sd/topics/topicgoogle_fb.gif",
#             "publishedAt": "2020-08-01T18:34:00Z",
#             "content": "YouTube is \"embroiled in a very public spat with songwriters and music publishers in Denmark,\" according to one music-industry news site. They cite Koda, the group that collects royalties and licensi\u2026 [+1421 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Android Police"
#             },
#             "author": "Ryne Hager",
#             "title": "Google Pixel 4a: Pricing, release date, specs, and more",
#             "description": "Google Pixel 4a: Pricing, release date, specs, and moreandroidpolice.com",
#             "url": "https://www.androidpolice.com/2020/08/01/pixel-4a-price-release-date-leaks-rumors-photos/",
#             "urlToImage": null,
#             "publishedAt": "2020-08-01T18:33:15Z",
#             "content": null
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "RaceFans"
#             },
#             "author": null,
#             "title": "Eric Ok posted an update in the group RaceFans site development: Your schedule on Google calendar shows the British GP [\u0085]",
#             "description": null,
#             "url": "https://www.racefans.net/members/ericok/activity/1024568/",
#             "urlToImage": "https://www.racefans.net/wp-content/themes/racefans/img/racefans-167-56.png",
#             "publishedAt": "2020-08-01T18:10:57Z",
#             "content": "Eric Ok posted an update in the group RaceFans site development29 minutes ago\r\nYour schedule on Google calendar shows the British GP qualifying and race starting at 10am Eastern Standard Time. It act\u2026 [+72 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Slickdeals.net"
#             },
#             "author": "iconian",
#             "title": "Lenovo w/ Google Assistant: Smart Clock $39, 8\" Smart Display $79, 10.1\" Smart Display $99 + free s/h",
#             "description": "Lenovo w/ Google Assistant: \n* Smart Clock [walmart.com] $39 \n* 8\" Smart Display [walmart.com] $79 \n* 10.1\" Smart Display [walmart.com] $99 \n \n+ free s/h",
#             "url": "https://slickdeals.net/f/14239721-lenovo-w-google-assistant-smart-clock-39-8-smart-display-79-10-1-smart-display-99-free-s-h",
#             "urlToImage": "https://static.slickdealscdn.com/attachment/9/5/3/2/3/9270845.attach",
#             "publishedAt": "2020-08-01T18:10:30Z",
#             "content": "Your vote will help the community find the best deals."
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "PhoneArena"
#             },
#             "author": "Joshua Swingle",
#             "title": "Google Pixel 4a detailed in full before launch: specs, cameras, price, availability",
#             "description": "Leaked Google Pixel 4a press rendersAfter several months of waiting, the Google Pixel 4 is now only two days away from being announced. But thanks to and an anonymous , there is now little reason to pay attention on Monday. The Google Pixel 4a is cheaper than\u2026",
#             "url": "https://www.phonearena.com/news/google-pixel-4a-specs-cameras-price-availability-leak_id126321",
#             "urlToImage": "https://m-cdn.phonearena.com/images/article/126321-two_1200/Google-Pixel-4a-detailed-in-full-before-launch-specs-cameras-price-availability.jpg",
#             "publishedAt": "2020-08-01T17:56:00Z",
#             "content": "All content, features, and design are Copyright 2001-2020 PhoneArena.com.PhoneArena may receive a small commission if you purchase through affiliate links on this page.All rights reserved. Reproducti\u2026 [+88 chars]"
#         },
#         {
#             "source": {
#                 "id": null,
#                 "name": "Researchbuzz.me"
#             },
#             "author": "ResearchBuzz",
#             "title": "The Thing BBS, Google, WhatsApp, More: Saturday ResearchBuzz, August 1, 2020",
#             "description": "NEW RESOURCES Rhizome: First Look: The Thing BBS. \u201cFounded by artist Wolfgang Staehle, The Thing made up just a few of the tens of thousands of BBSs that flourished in the years preceding the\u2026",
#             "url": "https://researchbuzz.me/2020/08/01/the-thing-bbs-google-whatsapp-more-saturday-researchbuzz-august-1-2020/",
#             "urlToImage": "https://researchbuzz.files.wordpress.com/2017/03/0ztcusnw.png?w=200",
#             "publishedAt": "2020-08-01T17:38:52Z",
#             "content": "NEW RESOURCES\r\nRhizome: First Look: The Thing BBS. \u201cFounded by artist Wolfgang Staehle, The Thing made up just a few of the tens of thousands of BBSs that flourished in the years preceding the popula\u2026 [+6423 chars]"
#         }
#     ]
# }
